# %%
import json
import shutil
from dataclasses import dataclass
from pathlib import Path
from typing import Optional

import math
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sqlalchemy import select, BinaryExpression, func

from databases.db_models import DBPost
from databases.external import DBConfig, SQliteConnection
from databases.platform_db_mgmt import PlatformDB
from src.const import BASE_DATA_PATH

stats_copy_path = BASE_DATA_PATH / "stats_copy.sqlite"
from dataclasses import field
from collections import Counter
from datetime import date
from databases.external import ClientTaskConfig
from calendar import monthrange
from datetime import datetime, time
import pytz

# %%
def make_stats_copy(db_path: Path):
    shutil.copy(db_path, stats_copy_path)


make_stats_copy(BASE_DATA_PATH / "twitter_20_01_2025_backup.sqlite")

# old..
platform_db = PlatformDB("twitter", DBConfig(db_connection=SQliteConnection(db_path=stats_copy_path)))

db = platform_db.db_mgmt
# Out:
# 2025-01-29 15:05:20,180 - ...Databases.databases.db_mgmt - DEBUG - creating db engine with sqlite:////home/rsoleyma/projects/platforms-clients/data/stats_copy.sqlite

# %%
def get_all_posts_sorted(platform: str,
                         conditions: Optional[BinaryExpression | list[BinaryExpression]] = None
                         ) -> list[DBPost]:
    with db.get_session() as session:
        # Start with a base query
        query = select(DBPost)

        # Platform is required
        query = query.where(DBPost.platform == platform)

        if conditions is not None:
            if isinstance(conditions, list):
                for condition in conditions:
                    query = query.where(condition)
            else:
                query = query.where(conditions)

        query.order_by(DBPost.date_created)
        # Execute the query and return the results
        result = session.execute(query)
        for post in result.scalars():
            yield post.model()

# %%
from databases.model_conversion import PostModel
from typing import Iterator

posts: Iterator[PostModel] = get_all_posts_sorted("twitter")
labeled_posts: list[PostModel] = []
for post in posts:
    labels = post.metadata_content_model.labels
    if labels:
        labeled_posts.append(post)
# Out:
# /tmp/ipykernel_12727/2120273466.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) metadata_content_model. (just use metadata_content)
#   labels = post.metadata_content_model.labels

# %%
all_datetimes: list[datetime] = []

for post in labeled_posts:
    all_datetimes.append(post.date_created)

all_datetimes.sort()

# %%
from datetime import timedelta


@dataclass(frozen=True)
class PostRange:
    year: int
    month: int
    day: int
    hour: int


def create_all_dt_tuples(start: datetime, end: datetime, exclude_end: Optional[bool] = True) -> list[PostRange]:
    current = start
    all_ranges: list[PostRange] = []
    while current <= end:
        all_ranges.append(PostRange(year=current.year, month=current.month, day=current.day, hour=current.hour))
        current += timedelta(hours=1)
    if exclude_end:
        all_ranges.pop(-1)
    return all_ranges

required_times = create_all_dt_tuples(datetime(2023, 1, 1), datetime(2023, 5, 1), exclude_end=True)
time_counter = Counter({t: 0 for t in required_times})

# %%
for d in all_datetimes:
    pr = PostRange(year=d.year, month=d.month, day=d.day, hour=d.hour)
    time_counter[pr] += 1

# %%
for t, c in time_counter.items():
    if c != 1:
        print(f"{t}: {c}")
# Out:
# PostRange(year=2023, month=1, day=1, hour=23): 0
# PostRange(year=2023, month=1, day=2, hour=0): 0
# PostRange(year=2023, month=1, day=2, hour=2): 2
# PostRange(year=2023, month=1, day=2, hour=5): 0
# PostRange(year=2023, month=1, day=2, hour=6): 0
# PostRange(year=2023, month=1, day=2, hour=7): 3
# PostRange(year=2023, month=1, day=2, hour=9): 0
# PostRange(year=2023, month=1, day=2, hour=11): 0
# PostRange(year=2023, month=1, day=2, hour=12): 0
# PostRange(year=2023, month=1, day=2, hour=13): 2
# PostRange(year=2023, month=1, day=2, hour=15): 0
# PostRange(year=2023, month=1, day=2, hour=17): 2
# PostRange(year=2023, month=1, day=2, hour=18): 0
# PostRange(year=2023, month=1, day=2, hour=19): 2
# PostRange(year=2023, month=1, day=2, hour=21): 2
# PostRange(year=2023, month=1, day=2, hour=22): 0
# PostRange(year=2023, month=1, day=2, hour=23): 3
# PostRange(year=2023, month=1, day=3, hour=0): 0
# PostRange(year=2023, month=1, day=3, hour=2): 0
# PostRange(year=2023, month=1, day=3, hour=4): 0
# PostRange(year=2023, month=1, day=3, hour=5): 0
# PostRange(year=2023, month=1, day=3, hour=8): 0
# PostRange(year=2023, month=1, day=3, hour=9): 2
# PostRange(year=2023, month=1, day=3, hour=10): 2
# PostRange(year=2023, month=1, day=3, hour=14): 0
# PostRange(year=2023, month=1, day=3, hour=15): 0
# PostRange(year=2023, month=1, day=3, hour=16): 2
# PostRange(year=2023, month=1, day=3, hour=18): 0
# PostRange(year=2023, month=1, day=3, hour=19): 2
# PostRange(year=2023, month=1, day=3, hour=22): 4
# PostRange(year=2023, month=1, day=3, hour=23): 0
# PostRange(year=2023, month=1, day=4, hour=1): 0
# PostRange(year=2023, month=1, day=4, hour=3): 0
# PostRange(year=2023, month=1, day=4, hour=4): 0
# PostRange(year=2023, month=1, day=4, hour=6): 2
# PostRange(year=2023, month=1, day=4, hour=9): 3
# PostRange(year=2023, month=1, day=4, hour=11): 2
# PostRange(year=2023, month=1, day=4, hour=12): 0
# PostRange(year=2023, month=1, day=4, hour=13): 0
# PostRange(year=2023, month=1, day=4, hour=15): 2
# PostRange(year=2023, month=1, day=4, hour=19): 0
# PostRange(year=2023, month=1, day=4, hour=21): 0
# PostRange(year=2023, month=1, day=4, hour=22): 2
# PostRange(year=2023, month=1, day=5, hour=1): 2
# PostRange(year=2023, month=1, day=5, hour=3): 2
# PostRange(year=2023, month=1, day=5, hour=6): 2
# PostRange(year=2023, month=1, day=5, hour=10): 0
# PostRange(year=2023, month=1, day=5, hour=11): 4
# PostRange(year=2023, month=1, day=5, hour=12): 3
# PostRange(year=2023, month=1, day=5, hour=13): 0
# PostRange(year=2023, month=1, day=5, hour=16): 2
# PostRange(year=2023, month=1, day=5, hour=22): 0
# PostRange(year=2023, month=1, day=6, hour=0): 2
# PostRange(year=2023, month=1, day=6, hour=3): 2
# PostRange(year=2023, month=1, day=6, hour=4): 3
# PostRange(year=2023, month=1, day=6, hour=5): 2
# PostRange(year=2023, month=1, day=6, hour=7): 2
# PostRange(year=2023, month=1, day=6, hour=8): 2
# PostRange(year=2023, month=1, day=6, hour=12): 0
# PostRange(year=2023, month=1, day=6, hour=13): 0
# PostRange(year=2023, month=1, day=6, hour=14): 3
# PostRange(year=2023, month=1, day=6, hour=15): 0
# PostRange(year=2023, month=1, day=6, hour=17): 2
# PostRange(year=2023, month=1, day=6, hour=21): 2
# PostRange(year=2023, month=1, day=6, hour=23): 2
# PostRange(year=2023, month=1, day=7, hour=0): 0
# PostRange(year=2023, month=1, day=7, hour=1): 0
# PostRange(year=2023, month=1, day=7, hour=4): 0
# PostRange(year=2023, month=1, day=7, hour=5): 0
# PostRange(year=2023, month=1, day=7, hour=6): 0
# PostRange(year=2023, month=1, day=7, hour=8): 0
# PostRange(year=2023, month=1, day=7, hour=9): 0
# PostRange(year=2023, month=1, day=7, hour=10): 2
# PostRange(year=2023, month=1, day=7, hour=11): 3
# PostRange(year=2023, month=1, day=7, hour=12): 3
# PostRange(year=2023, month=1, day=7, hour=13): 2
# PostRange(year=2023, month=1, day=7, hour=14): 2
# PostRange(year=2023, month=1, day=7, hour=16): 3
# PostRange(year=2023, month=1, day=7, hour=17): 0
# PostRange(year=2023, month=1, day=7, hour=18): 3
# PostRange(year=2023, month=1, day=7, hour=20): 0
# PostRange(year=2023, month=1, day=7, hour=22): 0
# PostRange(year=2023, month=1, day=7, hour=23): 0
# PostRange(year=2023, month=1, day=8, hour=0): 2
# PostRange(year=2023, month=1, day=8, hour=1): 0
# PostRange(year=2023, month=1, day=8, hour=2): 2
# PostRange(year=2023, month=1, day=8, hour=3): 0
# PostRange(year=2023, month=1, day=8, hour=5): 0
# PostRange(year=2023, month=1, day=8, hour=6): 0
# PostRange(year=2023, month=1, day=8, hour=10): 2
# PostRange(year=2023, month=1, day=8, hour=12): 0
# PostRange(year=2023, month=1, day=8, hour=13): 2
# PostRange(year=2023, month=1, day=8, hour=15): 3
# PostRange(year=2023, month=1, day=8, hour=16): 2
# PostRange(year=2023, month=1, day=8, hour=18): 4
# PostRange(year=2023, month=1, day=8, hour=19): 0
# PostRange(year=2023, month=1, day=8, hour=22): 3
# PostRange(year=2023, month=1, day=8, hour=23): 3
# PostRange(year=2023, month=1, day=9, hour=0): 0
# PostRange(year=2023, month=1, day=9, hour=1): 0
# PostRange(year=2023, month=1, day=9, hour=2): 2
# PostRange(year=2023, month=1, day=9, hour=5): 2
# PostRange(year=2023, month=1, day=9, hour=6): 0
# PostRange(year=2023, month=1, day=9, hour=7): 0
# PostRange(year=2023, month=1, day=9, hour=8): 2
# PostRange(year=2023, month=1, day=9, hour=10): 0
# PostRange(year=2023, month=1, day=9, hour=12): 2
# PostRange(year=2023, month=1, day=9, hour=15): 2
# PostRange(year=2023, month=1, day=9, hour=18): 0
# PostRange(year=2023, month=1, day=9, hour=19): 0
# PostRange(year=2023, month=1, day=9, hour=20): 3
# PostRange(year=2023, month=1, day=9, hour=22): 2
# PostRange(year=2023, month=1, day=9, hour=23): 2
# PostRange(year=2023, month=1, day=10, hour=1): 2
# PostRange(year=2023, month=1, day=10, hour=4): 2
# PostRange(year=2023, month=1, day=10, hour=5): 0
# PostRange(year=2023, month=1, day=10, hour=7): 0
# PostRange(year=2023, month=1, day=10, hour=8): 0
# PostRange(year=2023, month=1, day=10, hour=9): 3
# PostRange(year=2023, month=1, day=10, hour=10): 2
# PostRange(year=2023, month=1, day=10, hour=11): 2
# PostRange(year=2023, month=1, day=10, hour=13): 2
# PostRange(year=2023, month=1, day=10, hour=18): 0
# PostRange(year=2023, month=1, day=10, hour=22): 0
# PostRange(year=2023, month=1, day=10, hour=23): 0
# PostRange(year=2023, month=1, day=11, hour=1): 0
# PostRange(year=2023, month=1, day=11, hour=3): 2
# PostRange(year=2023, month=1, day=11, hour=5): 0
# PostRange(year=2023, month=1, day=11, hour=6): 2
# PostRange(year=2023, month=1, day=11, hour=9): 0
# PostRange(year=2023, month=1, day=11, hour=15): 0
# PostRange(year=2023, month=1, day=11, hour=16): 3
# PostRange(year=2023, month=1, day=11, hour=17): 0
# PostRange(year=2023, month=1, day=11, hour=20): 2
# PostRange(year=2023, month=1, day=11, hour=23): 0
# PostRange(year=2023, month=1, day=12, hour=1): 0
# PostRange(year=2023, month=1, day=12, hour=5): 0
# PostRange(year=2023, month=1, day=12, hour=6): 2
# PostRange(year=2023, month=1, day=12, hour=8): 0
# PostRange(year=2023, month=1, day=12, hour=10): 2
# PostRange(year=2023, month=1, day=12, hour=11): 2
# PostRange(year=2023, month=1, day=12, hour=14): 0
# PostRange(year=2023, month=1, day=12, hour=15): 2
# PostRange(year=2023, month=1, day=12, hour=16): 3
# PostRange(year=2023, month=1, day=12, hour=19): 2
# PostRange(year=2023, month=1, day=12, hour=20): 0
# PostRange(year=2023, month=1, day=12, hour=21): 0
# PostRange(year=2023, month=1, day=12, hour=22): 2
# PostRange(year=2023, month=1, day=13, hour=1): 2
# PostRange(year=2023, month=1, day=13, hour=4): 2
# PostRange(year=2023, month=1, day=13, hour=5): 0
# PostRange(year=2023, month=1, day=13, hour=7): 0
# PostRange(year=2023, month=1, day=13, hour=10): 2
# PostRange(year=2023, month=1, day=13, hour=11): 3
# PostRange(year=2023, month=1, day=13, hour=17): 2
# PostRange(year=2023, month=1, day=13, hour=18): 3
# PostRange(year=2023, month=1, day=13, hour=19): 2
# PostRange(year=2023, month=1, day=13, hour=20): 2
# PostRange(year=2023, month=1, day=13, hour=22): 0
# PostRange(year=2023, month=1, day=13, hour=23): 2
# PostRange(year=2023, month=1, day=14, hour=3): 0
# PostRange(year=2023, month=1, day=14, hour=5): 3
# PostRange(year=2023, month=1, day=14, hour=9): 2
# PostRange(year=2023, month=1, day=14, hour=10): 2
# PostRange(year=2023, month=1, day=14, hour=12): 3
# PostRange(year=2023, month=1, day=14, hour=13): 0
# PostRange(year=2023, month=1, day=14, hour=15): 3
# PostRange(year=2023, month=1, day=14, hour=16): 0
# PostRange(year=2023, month=1, day=14, hour=22): 0
# PostRange(year=2023, month=1, day=15, hour=1): 2
# PostRange(year=2023, month=1, day=15, hour=4): 0
# PostRange(year=2023, month=1, day=15, hour=5): 2
# PostRange(year=2023, month=1, day=15, hour=6): 0
# PostRange(year=2023, month=1, day=15, hour=7): 0
# PostRange(year=2023, month=1, day=15, hour=8): 2
# PostRange(year=2023, month=1, day=15, hour=10): 0
# PostRange(year=2023, month=1, day=15, hour=11): 2
# PostRange(year=2023, month=1, day=15, hour=12): 2
# PostRange(year=2023, month=1, day=15, hour=14): 0
# PostRange(year=2023, month=1, day=15, hour=15): 2
# PostRange(year=2023, month=1, day=15, hour=19): 2
# PostRange(year=2023, month=1, day=15, hour=20): 2
# PostRange(year=2023, month=1, day=15, hour=21): 2
# PostRange(year=2023, month=1, day=15, hour=22): 0
# PostRange(year=2023, month=1, day=15, hour=23): 2
# PostRange(year=2023, month=1, day=16, hour=0): 0
# PostRange(year=2023, month=1, day=16, hour=1): 0
# PostRange(year=2023, month=1, day=16, hour=4): 0
# PostRange(year=2023, month=1, day=16, hour=5): 0
# PostRange(year=2023, month=1, day=16, hour=7): 2
# PostRange(year=2023, month=1, day=16, hour=8): 2
# PostRange(year=2023, month=1, day=16, hour=9): 0
# PostRange(year=2023, month=1, day=16, hour=10): 2
# PostRange(year=2023, month=1, day=16, hour=13): 0
# PostRange(year=2023, month=1, day=16, hour=17): 2
# PostRange(year=2023, month=1, day=16, hour=18): 2
# PostRange(year=2023, month=1, day=16, hour=20): 0
# PostRange(year=2023, month=1, day=16, hour=22): 0
# PostRange(year=2023, month=1, day=17, hour=2): 0
# PostRange(year=2023, month=1, day=17, hour=3): 0
# PostRange(year=2023, month=1, day=17, hour=4): 0
# PostRange(year=2023, month=1, day=17, hour=5): 0
# PostRange(year=2023, month=1, day=17, hour=6): 0
# PostRange(year=2023, month=1, day=17, hour=7): 3
# PostRange(year=2023, month=1, day=17, hour=9): 0
# PostRange(year=2023, month=1, day=17, hour=11): 2
# PostRange(year=2023, month=1, day=17, hour=13): 0
# PostRange(year=2023, month=1, day=17, hour=14): 2
# PostRange(year=2023, month=1, day=17, hour=15): 2
# PostRange(year=2023, month=1, day=17, hour=17): 0
# PostRange(year=2023, month=1, day=17, hour=18): 2
# PostRange(year=2023, month=1, day=17, hour=19): 2
# PostRange(year=2023, month=1, day=17, hour=20): 2
# PostRange(year=2023, month=1, day=17, hour=21): 0
# PostRange(year=2023, month=1, day=17, hour=22): 0
# PostRange(year=2023, month=1, day=18, hour=2): 2
# PostRange(year=2023, month=1, day=18, hour=3): 0
# PostRange(year=2023, month=1, day=18, hour=5): 2
# PostRange(year=2023, month=1, day=18, hour=8): 3
# PostRange(year=2023, month=1, day=18, hour=9): 2
# PostRange(year=2023, month=1, day=18, hour=10): 3
# PostRange(year=2023, month=1, day=18, hour=11): 2
# PostRange(year=2023, month=1, day=18, hour=13): 2
# PostRange(year=2023, month=1, day=18, hour=14): 2
# PostRange(year=2023, month=1, day=18, hour=15): 2
# PostRange(year=2023, month=1, day=18, hour=17): 0
# PostRange(year=2023, month=1, day=18, hour=20): 2
# PostRange(year=2023, month=1, day=18, hour=21): 0
# PostRange(year=2023, month=1, day=18, hour=22): 2
# PostRange(year=2023, month=1, day=19, hour=0): 0
# PostRange(year=2023, month=1, day=19, hour=1): 3
# PostRange(year=2023, month=1, day=19, hour=3): 2
# PostRange(year=2023, month=1, day=19, hour=6): 2
# PostRange(year=2023, month=1, day=19, hour=7): 0
# PostRange(year=2023, month=1, day=19, hour=8): 0
# PostRange(year=2023, month=1, day=19, hour=10): 0
# PostRange(year=2023, month=1, day=19, hour=11): 2
# PostRange(year=2023, month=1, day=19, hour=12): 2
# PostRange(year=2023, month=1, day=19, hour=13): 2
# PostRange(year=2023, month=1, day=19, hour=15): 0
# PostRange(year=2023, month=1, day=19, hour=17): 2
# PostRange(year=2023, month=1, day=19, hour=23): 0
# PostRange(year=2023, month=1, day=20, hour=0): 0
# PostRange(year=2023, month=1, day=20, hour=1): 0
# PostRange(year=2023, month=1, day=20, hour=2): 0
# PostRange(year=2023, month=1, day=20, hour=3): 0
# PostRange(year=2023, month=1, day=20, hour=5): 2
# PostRange(year=2023, month=1, day=20, hour=7): 0
# PostRange(year=2023, month=1, day=20, hour=10): 2
# PostRange(year=2023, month=1, day=20, hour=12): 3
# PostRange(year=2023, month=1, day=20, hour=13): 0
# PostRange(year=2023, month=1, day=20, hour=14): 0
# PostRange(year=2023, month=1, day=20, hour=15): 3
# PostRange(year=2023, month=1, day=20, hour=17): 0
# PostRange(year=2023, month=1, day=20, hour=18): 4
# PostRange(year=2023, month=1, day=20, hour=19): 0
# PostRange(year=2023, month=1, day=20, hour=20): 0
# PostRange(year=2023, month=1, day=20, hour=22): 2
# PostRange(year=2023, month=1, day=20, hour=23): 0
# PostRange(year=2023, month=1, day=21, hour=0): 3
# PostRange(year=2023, month=1, day=21, hour=2): 0
# PostRange(year=2023, month=1, day=21, hour=4): 0
# PostRange(year=2023, month=1, day=21, hour=5): 0
# PostRange(year=2023, month=1, day=21, hour=6): 0
# PostRange(year=2023, month=1, day=21, hour=10): 0
# PostRange(year=2023, month=1, day=21, hour=13): 2
# PostRange(year=2023, month=1, day=21, hour=15): 0
# PostRange(year=2023, month=1, day=21, hour=16): 2
# PostRange(year=2023, month=1, day=21, hour=17): 2
# PostRange(year=2023, month=1, day=21, hour=18): 2
# PostRange(year=2023, month=1, day=21, hour=23): 0
# PostRange(year=2023, month=1, day=22, hour=0): 0
# PostRange(year=2023, month=1, day=22, hour=1): 2
# PostRange(year=2023, month=1, day=22, hour=2): 0
# PostRange(year=2023, month=1, day=22, hour=4): 0
# PostRange(year=2023, month=1, day=22, hour=6): 0
# PostRange(year=2023, month=1, day=22, hour=11): 2
# PostRange(year=2023, month=1, day=22, hour=13): 0
# PostRange(year=2023, month=1, day=22, hour=16): 3
# PostRange(year=2023, month=1, day=22, hour=18): 0
# PostRange(year=2023, month=1, day=22, hour=19): 0
# PostRange(year=2023, month=1, day=22, hour=22): 0
# PostRange(year=2023, month=1, day=23, hour=3): 3
# PostRange(year=2023, month=1, day=23, hour=4): 0
# PostRange(year=2023, month=1, day=23, hour=9): 3
# PostRange(year=2023, month=1, day=23, hour=10): 2
# PostRange(year=2023, month=1, day=23, hour=11): 2
# PostRange(year=2023, month=1, day=23, hour=12): 3
# PostRange(year=2023, month=1, day=23, hour=13): 0
# PostRange(year=2023, month=1, day=23, hour=15): 2
# PostRange(year=2023, month=1, day=23, hour=16): 0
# PostRange(year=2023, month=1, day=23, hour=17): 3
# PostRange(year=2023, month=1, day=23, hour=18): 2
# PostRange(year=2023, month=1, day=23, hour=22): 0
# PostRange(year=2023, month=1, day=23, hour=23): 0
# PostRange(year=2023, month=1, day=24, hour=1): 0
# PostRange(year=2023, month=1, day=24, hour=3): 2
# PostRange(year=2023, month=1, day=24, hour=4): 2
# PostRange(year=2023, month=1, day=24, hour=6): 2
# PostRange(year=2023, month=1, day=24, hour=8): 2
# PostRange(year=2023, month=1, day=24, hour=11): 3
# PostRange(year=2023, month=1, day=24, hour=12): 3
# PostRange(year=2023, month=1, day=24, hour=13): 2
# PostRange(year=2023, month=1, day=24, hour=15): 0
# PostRange(year=2023, month=1, day=24, hour=17): 3
# PostRange(year=2023, month=1, day=24, hour=19): 3
# PostRange(year=2023, month=1, day=24, hour=20): 2
# PostRange(year=2023, month=1, day=24, hour=22): 2
# PostRange(year=2023, month=1, day=24, hour=23): 3
# PostRange(year=2023, month=1, day=25, hour=1): 0
# PostRange(year=2023, month=1, day=25, hour=3): 0
# PostRange(year=2023, month=1, day=25, hour=4): 2
# PostRange(year=2023, month=1, day=25, hour=5): 2
# PostRange(year=2023, month=1, day=25, hour=7): 0
# PostRange(year=2023, month=1, day=25, hour=9): 3
# PostRange(year=2023, month=1, day=25, hour=10): 2
# PostRange(year=2023, month=1, day=25, hour=11): 0
# PostRange(year=2023, month=1, day=25, hour=12): 2
# PostRange(year=2023, month=1, day=25, hour=14): 3
# PostRange(year=2023, month=1, day=25, hour=18): 2
# PostRange(year=2023, month=1, day=25, hour=20): 0
# PostRange(year=2023, month=1, day=25, hour=21): 2
# PostRange(year=2023, month=1, day=26, hour=0): 3
# PostRange(year=2023, month=1, day=26, hour=2): 0
# PostRange(year=2023, month=1, day=26, hour=4): 2
# PostRange(year=2023, month=1, day=26, hour=6): 2
# PostRange(year=2023, month=1, day=26, hour=7): 2
# PostRange(year=2023, month=1, day=26, hour=8): 0
# PostRange(year=2023, month=1, day=26, hour=9): 2
# PostRange(year=2023, month=1, day=26, hour=10): 3
# PostRange(year=2023, month=1, day=26, hour=14): 0
# PostRange(year=2023, month=1, day=26, hour=15): 0
# PostRange(year=2023, month=1, day=26, hour=16): 3
# PostRange(year=2023, month=1, day=26, hour=18): 0
# PostRange(year=2023, month=1, day=26, hour=19): 0
# PostRange(year=2023, month=1, day=26, hour=20): 0
# PostRange(year=2023, month=1, day=26, hour=21): 2
# PostRange(year=2023, month=1, day=26, hour=22): 0
# PostRange(year=2023, month=1, day=27, hour=0): 2
# PostRange(year=2023, month=1, day=27, hour=2): 0
# PostRange(year=2023, month=1, day=27, hour=4): 3
# PostRange(year=2023, month=1, day=27, hour=5): 3
# PostRange(year=2023, month=1, day=27, hour=6): 0
# PostRange(year=2023, month=1, day=27, hour=8): 0
# PostRange(year=2023, month=1, day=27, hour=10): 0
# PostRange(year=2023, month=1, day=27, hour=11): 2
# PostRange(year=2023, month=1, day=27, hour=12): 0
# PostRange(year=2023, month=1, day=27, hour=13): 2
# PostRange(year=2023, month=1, day=27, hour=14): 0
# PostRange(year=2023, month=1, day=27, hour=15): 0
# PostRange(year=2023, month=1, day=27, hour=16): 2
# PostRange(year=2023, month=1, day=27, hour=21): 0
# PostRange(year=2023, month=1, day=27, hour=22): 0
# PostRange(year=2023, month=1, day=28, hour=0): 0
# PostRange(year=2023, month=1, day=28, hour=2): 0
# PostRange(year=2023, month=1, day=28, hour=4): 0
# PostRange(year=2023, month=1, day=28, hour=6): 0
# PostRange(year=2023, month=1, day=28, hour=8): 3
# PostRange(year=2023, month=1, day=28, hour=10): 3
# PostRange(year=2023, month=1, day=28, hour=14): 2
# PostRange(year=2023, month=1, day=28, hour=15): 2
# PostRange(year=2023, month=1, day=28, hour=16): 2
# PostRange(year=2023, month=1, day=28, hour=19): 2
# PostRange(year=2023, month=1, day=28, hour=21): 3
# PostRange(year=2023, month=1, day=29, hour=0): 0
# PostRange(year=2023, month=1, day=29, hour=1): 2
# PostRange(year=2023, month=1, day=29, hour=2): 0
# PostRange(year=2023, month=1, day=29, hour=4): 0
# PostRange(year=2023, month=1, day=29, hour=5): 2
# PostRange(year=2023, month=1, day=29, hour=6): 0
# PostRange(year=2023, month=1, day=29, hour=8): 0
# PostRange(year=2023, month=1, day=29, hour=9): 0
# PostRange(year=2023, month=1, day=29, hour=13): 0
# PostRange(year=2023, month=1, day=29, hour=14): 3
# PostRange(year=2023, month=1, day=29, hour=17): 2
# PostRange(year=2023, month=1, day=29, hour=18): 2
# PostRange(year=2023, month=1, day=29, hour=19): 3
# PostRange(year=2023, month=1, day=29, hour=23): 0
# PostRange(year=2023, month=1, day=30, hour=0): 0
# PostRange(year=2023, month=1, day=30, hour=8): 0
# PostRange(year=2023, month=1, day=30, hour=9): 2
# PostRange(year=2023, month=1, day=30, hour=12): 2
# PostRange(year=2023, month=1, day=30, hour=13): 0
# PostRange(year=2023, month=1, day=30, hour=15): 3
# PostRange(year=2023, month=1, day=30, hour=19): 0
# PostRange(year=2023, month=1, day=30, hour=21): 2
# PostRange(year=2023, month=1, day=31, hour=0): 2
# PostRange(year=2023, month=1, day=31, hour=1): 0
# PostRange(year=2023, month=1, day=31, hour=3): 0
# PostRange(year=2023, month=1, day=31, hour=4): 2
# PostRange(year=2023, month=1, day=31, hour=5): 2
# PostRange(year=2023, month=1, day=31, hour=7): 0
# PostRange(year=2023, month=1, day=31, hour=11): 2
# PostRange(year=2023, month=1, day=31, hour=12): 0
# PostRange(year=2023, month=1, day=31, hour=19): 2
# PostRange(year=2023, month=1, day=31, hour=23): 0
# PostRange(year=2023, month=2, day=1, hour=0): 0
# PostRange(year=2023, month=2, day=1, hour=1): 0
# PostRange(year=2023, month=2, day=1, hour=2): 3
# PostRange(year=2023, month=2, day=1, hour=4): 3
# PostRange(year=2023, month=2, day=1, hour=5): 2
# PostRange(year=2023, month=2, day=1, hour=7): 0
# PostRange(year=2023, month=2, day=1, hour=8): 0
# PostRange(year=2023, month=2, day=1, hour=11): 0
# PostRange(year=2023, month=2, day=1, hour=13): 0
# PostRange(year=2023, month=2, day=1, hour=16): 0
# PostRange(year=2023, month=2, day=1, hour=17): 2
# PostRange(year=2023, month=2, day=1, hour=18): 0
# PostRange(year=2023, month=2, day=1, hour=19): 0
# PostRange(year=2023, month=2, day=1, hour=20): 0
# PostRange(year=2023, month=2, day=1, hour=22): 2
# PostRange(year=2023, month=2, day=1, hour=23): 4
# PostRange(year=2023, month=2, day=2, hour=0): 2
# PostRange(year=2023, month=2, day=2, hour=1): 0
# PostRange(year=2023, month=2, day=2, hour=3): 3
# PostRange(year=2023, month=2, day=2, hour=4): 0
# PostRange(year=2023, month=2, day=2, hour=5): 0
# PostRange(year=2023, month=2, day=2, hour=6): 0
# PostRange(year=2023, month=2, day=2, hour=8): 3
# PostRange(year=2023, month=2, day=2, hour=9): 2
# PostRange(year=2023, month=2, day=2, hour=10): 0
# PostRange(year=2023, month=2, day=2, hour=12): 0
# PostRange(year=2023, month=2, day=2, hour=13): 0
# PostRange(year=2023, month=2, day=2, hour=15): 4
# PostRange(year=2023, month=2, day=2, hour=16): 2
# PostRange(year=2023, month=2, day=2, hour=17): 3
# PostRange(year=2023, month=2, day=2, hour=21): 0
# PostRange(year=2023, month=2, day=2, hour=22): 2
# PostRange(year=2023, month=2, day=2, hour=23): 2
# PostRange(year=2023, month=2, day=3, hour=0): 0
# PostRange(year=2023, month=2, day=3, hour=3): 0
# PostRange(year=2023, month=2, day=3, hour=4): 0
# PostRange(year=2023, month=2, day=3, hour=6): 0
# PostRange(year=2023, month=2, day=3, hour=7): 0
# PostRange(year=2023, month=2, day=3, hour=8): 2
# PostRange(year=2023, month=2, day=3, hour=9): 2
# PostRange(year=2023, month=2, day=3, hour=10): 2
# PostRange(year=2023, month=2, day=3, hour=12): 2
# PostRange(year=2023, month=2, day=3, hour=15): 2
# PostRange(year=2023, month=2, day=3, hour=16): 0
# PostRange(year=2023, month=2, day=3, hour=17): 3
# PostRange(year=2023, month=2, day=3, hour=20): 0
# PostRange(year=2023, month=2, day=3, hour=22): 2
# PostRange(year=2023, month=2, day=4, hour=0): 2
# PostRange(year=2023, month=2, day=4, hour=1): 0
# PostRange(year=2023, month=2, day=4, hour=3): 2
# PostRange(year=2023, month=2, day=4, hour=4): 0
# PostRange(year=2023, month=2, day=4, hour=6): 0
# PostRange(year=2023, month=2, day=4, hour=7): 0
# PostRange(year=2023, month=2, day=4, hour=8): 2
# PostRange(year=2023, month=2, day=4, hour=9): 0
# PostRange(year=2023, month=2, day=4, hour=16): 2
# PostRange(year=2023, month=2, day=4, hour=17): 0
# PostRange(year=2023, month=2, day=4, hour=21): 0
# PostRange(year=2023, month=2, day=4, hour=22): 0
# PostRange(year=2023, month=2, day=4, hour=23): 2
# PostRange(year=2023, month=2, day=5, hour=0): 0
# PostRange(year=2023, month=2, day=5, hour=5): 0
# PostRange(year=2023, month=2, day=5, hour=6): 2
# PostRange(year=2023, month=2, day=5, hour=7): 0
# PostRange(year=2023, month=2, day=5, hour=8): 0
# PostRange(year=2023, month=2, day=5, hour=9): 0
# PostRange(year=2023, month=2, day=5, hour=13): 2
# PostRange(year=2023, month=2, day=5, hour=16): 2
# PostRange(year=2023, month=2, day=5, hour=18): 2
# PostRange(year=2023, month=2, day=5, hour=19): 2
# PostRange(year=2023, month=2, day=5, hour=20): 0
# PostRange(year=2023, month=2, day=5, hour=22): 0
# PostRange(year=2023, month=2, day=6, hour=0): 2
# PostRange(year=2023, month=2, day=6, hour=2): 0
# PostRange(year=2023, month=2, day=6, hour=4): 0
# PostRange(year=2023, month=2, day=6, hour=5): 0
# PostRange(year=2023, month=2, day=6, hour=6): 3
# PostRange(year=2023, month=2, day=6, hour=7): 0
# PostRange(year=2023, month=2, day=6, hour=8): 3
# PostRange(year=2023, month=2, day=6, hour=9): 0
# PostRange(year=2023, month=2, day=6, hour=10): 0
# PostRange(year=2023, month=2, day=6, hour=11): 0
# PostRange(year=2023, month=2, day=6, hour=12): 2
# PostRange(year=2023, month=2, day=6, hour=13): 0
# PostRange(year=2023, month=2, day=6, hour=15): 0
# PostRange(year=2023, month=2, day=6, hour=16): 2
# PostRange(year=2023, month=2, day=6, hour=17): 2
# PostRange(year=2023, month=2, day=6, hour=18): 2
# PostRange(year=2023, month=2, day=6, hour=22): 4
# PostRange(year=2023, month=2, day=7, hour=0): 2
# PostRange(year=2023, month=2, day=7, hour=1): 2
# PostRange(year=2023, month=2, day=7, hour=3): 0
# PostRange(year=2023, month=2, day=7, hour=4): 0
# PostRange(year=2023, month=2, day=7, hour=6): 0
# PostRange(year=2023, month=2, day=7, hour=7): 0
# PostRange(year=2023, month=2, day=7, hour=8): 0
# PostRange(year=2023, month=2, day=7, hour=10): 4
# PostRange(year=2023, month=2, day=7, hour=11): 2
# PostRange(year=2023, month=2, day=7, hour=13): 3
# PostRange(year=2023, month=2, day=7, hour=14): 2
# PostRange(year=2023, month=2, day=7, hour=17): 0
# PostRange(year=2023, month=2, day=7, hour=18): 2
# PostRange(year=2023, month=2, day=7, hour=19): 2
# PostRange(year=2023, month=2, day=7, hour=21): 2
# PostRange(year=2023, month=2, day=7, hour=22): 2
# PostRange(year=2023, month=2, day=8, hour=0): 0
# PostRange(year=2023, month=2, day=8, hour=3): 2
# PostRange(year=2023, month=2, day=8, hour=4): 0
# PostRange(year=2023, month=2, day=8, hour=7): 4
# PostRange(year=2023, month=2, day=8, hour=8): 4
# PostRange(year=2023, month=2, day=8, hour=9): 2
# PostRange(year=2023, month=2, day=8, hour=11): 2
# PostRange(year=2023, month=2, day=8, hour=13): 2
# PostRange(year=2023, month=2, day=8, hour=18): 2
# PostRange(year=2023, month=2, day=8, hour=19): 0
# PostRange(year=2023, month=2, day=8, hour=20): 2
# PostRange(year=2023, month=2, day=8, hour=22): 2
# PostRange(year=2023, month=2, day=9, hour=0): 0
# PostRange(year=2023, month=2, day=9, hour=2): 0
# PostRange(year=2023, month=2, day=9, hour=3): 0
# PostRange(year=2023, month=2, day=9, hour=8): 3
# PostRange(year=2023, month=2, day=9, hour=9): 3
# PostRange(year=2023, month=2, day=9, hour=10): 2
# PostRange(year=2023, month=2, day=9, hour=11): 0
# PostRange(year=2023, month=2, day=9, hour=14): 2
# PostRange(year=2023, month=2, day=9, hour=15): 3
# PostRange(year=2023, month=2, day=9, hour=16): 2
# PostRange(year=2023, month=2, day=9, hour=19): 3
# PostRange(year=2023, month=2, day=9, hour=21): 2
# PostRange(year=2023, month=2, day=10, hour=0): 0
# PostRange(year=2023, month=2, day=10, hour=1): 0
# PostRange(year=2023, month=2, day=10, hour=2): 0
# PostRange(year=2023, month=2, day=10, hour=3): 0
# PostRange(year=2023, month=2, day=10, hour=4): 2
# PostRange(year=2023, month=2, day=10, hour=5): 0
# PostRange(year=2023, month=2, day=10, hour=6): 0
# PostRange(year=2023, month=2, day=10, hour=7): 0
# PostRange(year=2023, month=2, day=10, hour=8): 3
# PostRange(year=2023, month=2, day=10, hour=10): 2
# PostRange(year=2023, month=2, day=10, hour=14): 0
# PostRange(year=2023, month=2, day=10, hour=19): 0
# PostRange(year=2023, month=2, day=10, hour=22): 2
# PostRange(year=2023, month=2, day=11, hour=0): 2
# PostRange(year=2023, month=2, day=11, hour=1): 2
# PostRange(year=2023, month=2, day=11, hour=2): 0
# PostRange(year=2023, month=2, day=11, hour=4): 2
# PostRange(year=2023, month=2, day=11, hour=5): 0
# PostRange(year=2023, month=2, day=11, hour=9): 2
# PostRange(year=2023, month=2, day=11, hour=10): 0
# PostRange(year=2023, month=2, day=11, hour=11): 0
# PostRange(year=2023, month=2, day=11, hour=12): 0
# PostRange(year=2023, month=2, day=11, hour=15): 0
# PostRange(year=2023, month=2, day=11, hour=17): 0
# PostRange(year=2023, month=2, day=11, hour=21): 0
# PostRange(year=2023, month=2, day=11, hour=22): 0
# PostRange(year=2023, month=2, day=12, hour=1): 2
# PostRange(year=2023, month=2, day=12, hour=2): 3
# PostRange(year=2023, month=2, day=12, hour=3): 0
# PostRange(year=2023, month=2, day=12, hour=4): 0
# PostRange(year=2023, month=2, day=12, hour=7): 0
# PostRange(year=2023, month=2, day=12, hour=9): 0
# PostRange(year=2023, month=2, day=12, hour=13): 0
# PostRange(year=2023, month=2, day=12, hour=14): 2
# PostRange(year=2023, month=2, day=12, hour=15): 2
# PostRange(year=2023, month=2, day=12, hour=16): 2
# PostRange(year=2023, month=2, day=12, hour=19): 2
# PostRange(year=2023, month=2, day=12, hour=20): 0
# PostRange(year=2023, month=2, day=12, hour=21): 3
# PostRange(year=2023, month=2, day=12, hour=22): 2
# PostRange(year=2023, month=2, day=12, hour=23): 2
# PostRange(year=2023, month=2, day=13, hour=0): 2
# PostRange(year=2023, month=2, day=13, hour=1): 0
# PostRange(year=2023, month=2, day=13, hour=3): 0
# PostRange(year=2023, month=2, day=13, hour=4): 2
# PostRange(year=2023, month=2, day=13, hour=5): 0
# PostRange(year=2023, month=2, day=13, hour=7): 0
# PostRange(year=2023, month=2, day=13, hour=8): 3
# PostRange(year=2023, month=2, day=13, hour=9): 3
# PostRange(year=2023, month=2, day=13, hour=11): 0
# PostRange(year=2023, month=2, day=13, hour=17): 0
# PostRange(year=2023, month=2, day=13, hour=18): 3
# PostRange(year=2023, month=2, day=13, hour=19): 2
# PostRange(year=2023, month=2, day=13, hour=20): 2
# PostRange(year=2023, month=2, day=13, hour=21): 2
# PostRange(year=2023, month=2, day=13, hour=22): 2
# PostRange(year=2023, month=2, day=13, hour=23): 2
# PostRange(year=2023, month=2, day=14, hour=3): 0
# PostRange(year=2023, month=2, day=14, hour=4): 0
# PostRange(year=2023, month=2, day=14, hour=6): 2
# PostRange(year=2023, month=2, day=14, hour=8): 0
# PostRange(year=2023, month=2, day=14, hour=9): 3
# PostRange(year=2023, month=2, day=14, hour=10): 2
# PostRange(year=2023, month=2, day=14, hour=12): 2
# PostRange(year=2023, month=2, day=14, hour=13): 3
# PostRange(year=2023, month=2, day=14, hour=14): 3
# PostRange(year=2023, month=2, day=14, hour=15): 0
# PostRange(year=2023, month=2, day=14, hour=16): 2
# PostRange(year=2023, month=2, day=14, hour=18): 0
# PostRange(year=2023, month=2, day=14, hour=19): 0
# PostRange(year=2023, month=2, day=14, hour=21): 4
# PostRange(year=2023, month=2, day=14, hour=22): 2
# PostRange(year=2023, month=2, day=15, hour=0): 2
# PostRange(year=2023, month=2, day=15, hour=2): 2
# PostRange(year=2023, month=2, day=15, hour=4): 0
# PostRange(year=2023, month=2, day=15, hour=10): 2
# PostRange(year=2023, month=2, day=15, hour=11): 2
# PostRange(year=2023, month=2, day=15, hour=14): 2
# PostRange(year=2023, month=2, day=15, hour=15): 0
# PostRange(year=2023, month=2, day=15, hour=18): 2
# PostRange(year=2023, month=2, day=15, hour=20): 2
# PostRange(year=2023, month=2, day=15, hour=21): 0
# PostRange(year=2023, month=2, day=15, hour=22): 0
# PostRange(year=2023, month=2, day=15, hour=23): 2
# PostRange(year=2023, month=2, day=16, hour=0): 2
# PostRange(year=2023, month=2, day=16, hour=2): 0
# PostRange(year=2023, month=2, day=16, hour=4): 0
# PostRange(year=2023, month=2, day=16, hour=5): 0
# PostRange(year=2023, month=2, day=16, hour=6): 4
# PostRange(year=2023, month=2, day=16, hour=7): 2
# PostRange(year=2023, month=2, day=16, hour=8): 2
# PostRange(year=2023, month=2, day=16, hour=12): 3
# PostRange(year=2023, month=2, day=16, hour=13): 3
# PostRange(year=2023, month=2, day=16, hour=18): 2
# PostRange(year=2023, month=2, day=16, hour=19): 0
# PostRange(year=2023, month=2, day=16, hour=21): 3
# PostRange(year=2023, month=2, day=17, hour=0): 0
# PostRange(year=2023, month=2, day=17, hour=2): 0
# PostRange(year=2023, month=2, day=17, hour=3): 0
# PostRange(year=2023, month=2, day=17, hour=4): 0
# PostRange(year=2023, month=2, day=17, hour=6): 0
# PostRange(year=2023, month=2, day=17, hour=7): 4
# PostRange(year=2023, month=2, day=17, hour=8): 2
# PostRange(year=2023, month=2, day=17, hour=9): 4
# PostRange(year=2023, month=2, day=17, hour=11): 2
# PostRange(year=2023, month=2, day=17, hour=14): 2
# PostRange(year=2023, month=2, day=17, hour=16): 0
# PostRange(year=2023, month=2, day=17, hour=17): 3
# PostRange(year=2023, month=2, day=17, hour=19): 0
# PostRange(year=2023, month=2, day=17, hour=20): 3
# PostRange(year=2023, month=2, day=17, hour=21): 2
# PostRange(year=2023, month=2, day=17, hour=22): 4
# PostRange(year=2023, month=2, day=17, hour=23): 0
# PostRange(year=2023, month=2, day=18, hour=0): 0
# PostRange(year=2023, month=2, day=18, hour=2): 0
# PostRange(year=2023, month=2, day=18, hour=3): 0
# PostRange(year=2023, month=2, day=18, hour=8): 2
# PostRange(year=2023, month=2, day=18, hour=9): 0
# PostRange(year=2023, month=2, day=18, hour=10): 2
# PostRange(year=2023, month=2, day=18, hour=11): 2
# PostRange(year=2023, month=2, day=18, hour=14): 0
# PostRange(year=2023, month=2, day=18, hour=16): 0
# PostRange(year=2023, month=2, day=18, hour=18): 0
# PostRange(year=2023, month=2, day=18, hour=19): 0
# PostRange(year=2023, month=2, day=18, hour=20): 2
# PostRange(year=2023, month=2, day=18, hour=21): 0
# PostRange(year=2023, month=2, day=18, hour=22): 2
# PostRange(year=2023, month=2, day=19, hour=0): 0
# PostRange(year=2023, month=2, day=19, hour=1): 0
# PostRange(year=2023, month=2, day=19, hour=3): 0
# PostRange(year=2023, month=2, day=19, hour=4): 0
# PostRange(year=2023, month=2, day=19, hour=6): 0
# PostRange(year=2023, month=2, day=19, hour=8): 0
# PostRange(year=2023, month=2, day=19, hour=10): 3
# PostRange(year=2023, month=2, day=19, hour=11): 2
# PostRange(year=2023, month=2, day=19, hour=12): 2
# PostRange(year=2023, month=2, day=19, hour=14): 0
# PostRange(year=2023, month=2, day=19, hour=15): 3
# PostRange(year=2023, month=2, day=19, hour=16): 2
# PostRange(year=2023, month=2, day=19, hour=17): 3
# PostRange(year=2023, month=2, day=19, hour=19): 0
# PostRange(year=2023, month=2, day=19, hour=22): 0
# PostRange(year=2023, month=2, day=19, hour=23): 2
# PostRange(year=2023, month=2, day=20, hour=0): 3
# PostRange(year=2023, month=2, day=20, hour=1): 0
# PostRange(year=2023, month=2, day=20, hour=2): 0
# PostRange(year=2023, month=2, day=20, hour=3): 2
# PostRange(year=2023, month=2, day=20, hour=4): 2
# PostRange(year=2023, month=2, day=20, hour=5): 0
# PostRange(year=2023, month=2, day=20, hour=6): 0
# PostRange(year=2023, month=2, day=20, hour=7): 0
# PostRange(year=2023, month=2, day=20, hour=12): 2
# PostRange(year=2023, month=2, day=20, hour=15): 2
# PostRange(year=2023, month=2, day=20, hour=18): 2
# PostRange(year=2023, month=2, day=20, hour=19): 3
# PostRange(year=2023, month=2, day=20, hour=20): 2
# PostRange(year=2023, month=2, day=20, hour=21): 3
# PostRange(year=2023, month=2, day=20, hour=22): 2
# PostRange(year=2023, month=2, day=21, hour=3): 3
# PostRange(year=2023, month=2, day=21, hour=4): 2
# PostRange(year=2023, month=2, day=21, hour=5): 2
# PostRange(year=2023, month=2, day=21, hour=6): 0
# PostRange(year=2023, month=2, day=21, hour=7): 0
# PostRange(year=2023, month=2, day=21, hour=9): 0
# PostRange(year=2023, month=2, day=21, hour=11): 2
# PostRange(year=2023, month=2, day=21, hour=12): 0
# PostRange(year=2023, month=2, day=21, hour=15): 0
# PostRange(year=2023, month=2, day=21, hour=16): 2
# PostRange(year=2023, month=2, day=21, hour=17): 2
# PostRange(year=2023, month=2, day=21, hour=18): 0
# PostRange(year=2023, month=2, day=21, hour=19): 2
# PostRange(year=2023, month=2, day=21, hour=20): 0
# PostRange(year=2023, month=2, day=21, hour=21): 2
# PostRange(year=2023, month=2, day=21, hour=22): 0
# PostRange(year=2023, month=2, day=22, hour=0): 0
# PostRange(year=2023, month=2, day=22, hour=2): 0
# PostRange(year=2023, month=2, day=22, hour=3): 0
# PostRange(year=2023, month=2, day=22, hour=4): 2
# PostRange(year=2023, month=2, day=22, hour=7): 3
# PostRange(year=2023, month=2, day=22, hour=9): 2
# PostRange(year=2023, month=2, day=22, hour=10): 2
# PostRange(year=2023, month=2, day=22, hour=11): 2
# PostRange(year=2023, month=2, day=22, hour=12): 0
# PostRange(year=2023, month=2, day=22, hour=13): 2
# PostRange(year=2023, month=2, day=22, hour=14): 2
# PostRange(year=2023, month=2, day=22, hour=17): 2
# PostRange(year=2023, month=2, day=22, hour=19): 3
# PostRange(year=2023, month=2, day=22, hour=21): 2
# PostRange(year=2023, month=2, day=22, hour=22): 3
# PostRange(year=2023, month=2, day=23, hour=0): 0
# PostRange(year=2023, month=2, day=23, hour=1): 0
# PostRange(year=2023, month=2, day=23, hour=2): 0
# PostRange(year=2023, month=2, day=23, hour=3): 2
# PostRange(year=2023, month=2, day=23, hour=4): 2
# PostRange(year=2023, month=2, day=23, hour=6): 0
# PostRange(year=2023, month=2, day=23, hour=9): 0
# PostRange(year=2023, month=2, day=23, hour=10): 3
# PostRange(year=2023, month=2, day=23, hour=11): 0
# PostRange(year=2023, month=2, day=23, hour=15): 3
# PostRange(year=2023, month=2, day=23, hour=16): 4
# PostRange(year=2023, month=2, day=23, hour=19): 3
# PostRange(year=2023, month=2, day=23, hour=20): 0
# PostRange(year=2023, month=2, day=23, hour=21): 0
# PostRange(year=2023, month=2, day=23, hour=23): 0
# PostRange(year=2023, month=2, day=24, hour=0): 2
# PostRange(year=2023, month=2, day=24, hour=1): 2
# PostRange(year=2023, month=2, day=24, hour=4): 0
# PostRange(year=2023, month=2, day=24, hour=5): 0
# PostRange(year=2023, month=2, day=24, hour=7): 2
# PostRange(year=2023, month=2, day=24, hour=8): 2
# PostRange(year=2023, month=2, day=24, hour=9): 3
# PostRange(year=2023, month=2, day=24, hour=13): 0
# PostRange(year=2023, month=2, day=24, hour=14): 3
# PostRange(year=2023, month=2, day=24, hour=15): 0
# PostRange(year=2023, month=2, day=24, hour=16): 3
# PostRange(year=2023, month=2, day=24, hour=18): 2
# PostRange(year=2023, month=2, day=24, hour=19): 2
# PostRange(year=2023, month=2, day=24, hour=20): 2
# PostRange(year=2023, month=2, day=24, hour=22): 3
# PostRange(year=2023, month=2, day=24, hour=23): 0
# PostRange(year=2023, month=2, day=25, hour=0): 0
# PostRange(year=2023, month=2, day=25, hour=1): 0
# PostRange(year=2023, month=2, day=25, hour=2): 0
# PostRange(year=2023, month=2, day=25, hour=3): 0
# PostRange(year=2023, month=2, day=25, hour=4): 2
# PostRange(year=2023, month=2, day=25, hour=6): 0
# PostRange(year=2023, month=2, day=25, hour=8): 2
# PostRange(year=2023, month=2, day=25, hour=10): 0
# PostRange(year=2023, month=2, day=25, hour=11): 0
# PostRange(year=2023, month=2, day=25, hour=12): 0
# PostRange(year=2023, month=2, day=25, hour=14): 0
# PostRange(year=2023, month=2, day=25, hour=19): 2
# PostRange(year=2023, month=2, day=25, hour=21): 2
# PostRange(year=2023, month=2, day=25, hour=22): 2
# PostRange(year=2023, month=2, day=26, hour=0): 2
# PostRange(year=2023, month=2, day=26, hour=2): 0
# PostRange(year=2023, month=2, day=26, hour=3): 2
# PostRange(year=2023, month=2, day=26, hour=4): 0
# PostRange(year=2023, month=2, day=26, hour=5): 2
# PostRange(year=2023, month=2, day=26, hour=6): 0
# PostRange(year=2023, month=2, day=26, hour=8): 0
# PostRange(year=2023, month=2, day=26, hour=9): 2
# PostRange(year=2023, month=2, day=26, hour=11): 2
# PostRange(year=2023, month=2, day=26, hour=13): 3
# PostRange(year=2023, month=2, day=26, hour=16): 2
# PostRange(year=2023, month=2, day=26, hour=17): 0
# PostRange(year=2023, month=2, day=26, hour=20): 0
# PostRange(year=2023, month=2, day=26, hour=23): 0
# PostRange(year=2023, month=2, day=27, hour=2): 0
# PostRange(year=2023, month=2, day=27, hour=4): 0
# PostRange(year=2023, month=2, day=27, hour=5): 0
# PostRange(year=2023, month=2, day=27, hour=6): 0
# PostRange(year=2023, month=2, day=27, hour=7): 2
# PostRange(year=2023, month=2, day=27, hour=9): 2
# PostRange(year=2023, month=2, day=27, hour=12): 4
# PostRange(year=2023, month=2, day=27, hour=13): 0
# PostRange(year=2023, month=2, day=27, hour=15): 3
# PostRange(year=2023, month=2, day=27, hour=17): 2
# PostRange(year=2023, month=2, day=27, hour=18): 3
# PostRange(year=2023, month=2, day=27, hour=19): 0
# PostRange(year=2023, month=2, day=27, hour=20): 0
# PostRange(year=2023, month=2, day=27, hour=22): 2
# PostRange(year=2023, month=2, day=27, hour=23): 2
# PostRange(year=2023, month=2, day=28, hour=0): 2
# PostRange(year=2023, month=2, day=28, hour=1): 0
# PostRange(year=2023, month=2, day=28, hour=3): 0
# PostRange(year=2023, month=2, day=28, hour=4): 3
# PostRange(year=2023, month=2, day=28, hour=5): 0
# PostRange(year=2023, month=2, day=28, hour=6): 2
# PostRange(year=2023, month=2, day=28, hour=7): 2
# PostRange(year=2023, month=2, day=28, hour=8): 0
# PostRange(year=2023, month=2, day=28, hour=10): 2
# PostRange(year=2023, month=2, day=28, hour=11): 2
# PostRange(year=2023, month=2, day=28, hour=12): 2
# PostRange(year=2023, month=2, day=28, hour=13): 2
# PostRange(year=2023, month=2, day=28, hour=18): 0
# PostRange(year=2023, month=2, day=28, hour=19): 2
# PostRange(year=2023, month=2, day=28, hour=20): 3
# PostRange(year=2023, month=2, day=28, hour=22): 0
# PostRange(year=2023, month=2, day=28, hour=23): 0
# PostRange(year=2023, month=3, day=1, hour=0): 0
# PostRange(year=2023, month=3, day=1, hour=1): 0
# PostRange(year=2023, month=3, day=1, hour=3): 2
# PostRange(year=2023, month=3, day=1, hour=5): 2
# PostRange(year=2023, month=3, day=1, hour=7): 3
# PostRange(year=2023, month=3, day=1, hour=8): 3
# PostRange(year=2023, month=3, day=1, hour=9): 2
# PostRange(year=2023, month=3, day=1, hour=10): 2
# PostRange(year=2023, month=3, day=1, hour=11): 2
# PostRange(year=2023, month=3, day=1, hour=13): 0
# PostRange(year=2023, month=3, day=1, hour=14): 2
# PostRange(year=2023, month=3, day=1, hour=15): 2
# PostRange(year=2023, month=3, day=1, hour=16): 2
# PostRange(year=2023, month=3, day=1, hour=18): 0
# PostRange(year=2023, month=3, day=1, hour=20): 0
# PostRange(year=2023, month=3, day=1, hour=22): 3
# PostRange(year=2023, month=3, day=1, hour=23): 2
# PostRange(year=2023, month=3, day=2, hour=0): 0
# PostRange(year=2023, month=3, day=2, hour=2): 0
# PostRange(year=2023, month=3, day=2, hour=3): 0
# PostRange(year=2023, month=3, day=2, hour=4): 2
# PostRange(year=2023, month=3, day=2, hour=5): 0
# PostRange(year=2023, month=3, day=2, hour=6): 0
# PostRange(year=2023, month=3, day=2, hour=7): 2
# PostRange(year=2023, month=3, day=2, hour=12): 2
# PostRange(year=2023, month=3, day=2, hour=14): 2
# PostRange(year=2023, month=3, day=2, hour=15): 3
# PostRange(year=2023, month=3, day=2, hour=16): 2
# PostRange(year=2023, month=3, day=2, hour=17): 2
# PostRange(year=2023, month=3, day=2, hour=18): 0
# PostRange(year=2023, month=3, day=2, hour=19): 3
# PostRange(year=2023, month=3, day=2, hour=20): 0
# PostRange(year=2023, month=3, day=2, hour=21): 2
# PostRange(year=2023, month=3, day=3, hour=1): 0
# PostRange(year=2023, month=3, day=3, hour=6): 0
# PostRange(year=2023, month=3, day=3, hour=7): 0
# PostRange(year=2023, month=3, day=3, hour=9): 2
# PostRange(year=2023, month=3, day=3, hour=10): 0
# PostRange(year=2023, month=3, day=3, hour=11): 2
# PostRange(year=2023, month=3, day=3, hour=12): 3
# PostRange(year=2023, month=3, day=3, hour=13): 2
# PostRange(year=2023, month=3, day=3, hour=18): 2
# PostRange(year=2023, month=3, day=3, hour=19): 0
# PostRange(year=2023, month=3, day=3, hour=23): 2
# PostRange(year=2023, month=3, day=4, hour=0): 0
# PostRange(year=2023, month=3, day=4, hour=3): 3
# PostRange(year=2023, month=3, day=4, hour=4): 2
# PostRange(year=2023, month=3, day=4, hour=6): 3
# PostRange(year=2023, month=3, day=4, hour=7): 0
# PostRange(year=2023, month=3, day=4, hour=8): 0
# PostRange(year=2023, month=3, day=4, hour=9): 2
# PostRange(year=2023, month=3, day=4, hour=10): 3
# PostRange(year=2023, month=3, day=4, hour=11): 2
# PostRange(year=2023, month=3, day=4, hour=12): 0
# PostRange(year=2023, month=3, day=4, hour=13): 2
# PostRange(year=2023, month=3, day=4, hour=15): 0
# PostRange(year=2023, month=3, day=4, hour=16): 3
# PostRange(year=2023, month=3, day=4, hour=18): 0
# PostRange(year=2023, month=3, day=4, hour=19): 3
# PostRange(year=2023, month=3, day=4, hour=21): 0
# PostRange(year=2023, month=3, day=4, hour=22): 0
# PostRange(year=2023, month=3, day=4, hour=23): 3
# PostRange(year=2023, month=3, day=5, hour=0): 2
# PostRange(year=2023, month=3, day=5, hour=2): 3
# PostRange(year=2023, month=3, day=5, hour=4): 0
# PostRange(year=2023, month=3, day=5, hour=6): 2
# PostRange(year=2023, month=3, day=5, hour=9): 0
# PostRange(year=2023, month=3, day=5, hour=10): 2
# PostRange(year=2023, month=3, day=5, hour=15): 0
# PostRange(year=2023, month=3, day=5, hour=18): 0
# PostRange(year=2023, month=3, day=5, hour=23): 2
# PostRange(year=2023, month=3, day=6, hour=2): 0
# PostRange(year=2023, month=3, day=6, hour=4): 2
# PostRange(year=2023, month=3, day=6, hour=6): 3
# PostRange(year=2023, month=3, day=6, hour=7): 3
# PostRange(year=2023, month=3, day=6, hour=8): 0
# PostRange(year=2023, month=3, day=6, hour=9): 0
# PostRange(year=2023, month=3, day=6, hour=11): 2
# PostRange(year=2023, month=3, day=6, hour=12): 3
# PostRange(year=2023, month=3, day=6, hour=14): 2
# PostRange(year=2023, month=3, day=6, hour=15): 2
# PostRange(year=2023, month=3, day=6, hour=16): 2
# PostRange(year=2023, month=3, day=6, hour=17): 2
# PostRange(year=2023, month=3, day=6, hour=18): 0
# PostRange(year=2023, month=3, day=6, hour=20): 2
# PostRange(year=2023, month=3, day=6, hour=21): 2
# PostRange(year=2023, month=3, day=7, hour=0): 3
# PostRange(year=2023, month=3, day=7, hour=1): 2
# PostRange(year=2023, month=3, day=7, hour=2): 0
# PostRange(year=2023, month=3, day=7, hour=7): 3
# PostRange(year=2023, month=3, day=7, hour=8): 2
# PostRange(year=2023, month=3, day=7, hour=10): 3
# PostRange(year=2023, month=3, day=7, hour=11): 2
# PostRange(year=2023, month=3, day=7, hour=13): 2
# PostRange(year=2023, month=3, day=7, hour=14): 2
# PostRange(year=2023, month=3, day=7, hour=15): 3
# PostRange(year=2023, month=3, day=7, hour=16): 2
# PostRange(year=2023, month=3, day=7, hour=18): 0
# PostRange(year=2023, month=3, day=7, hour=19): 0
# PostRange(year=2023, month=3, day=7, hour=20): 2
# PostRange(year=2023, month=3, day=7, hour=21): 3
# PostRange(year=2023, month=3, day=7, hour=22): 2
# PostRange(year=2023, month=3, day=8, hour=1): 2
# PostRange(year=2023, month=3, day=8, hour=2): 0
# PostRange(year=2023, month=3, day=8, hour=3): 0
# PostRange(year=2023, month=3, day=8, hour=4): 0
# PostRange(year=2023, month=3, day=8, hour=5): 4
# PostRange(year=2023, month=3, day=8, hour=6): 0
# PostRange(year=2023, month=3, day=8, hour=8): 0
# PostRange(year=2023, month=3, day=8, hour=10): 2
# PostRange(year=2023, month=3, day=8, hour=11): 2
# PostRange(year=2023, month=3, day=8, hour=12): 2
# PostRange(year=2023, month=3, day=8, hour=13): 3
# PostRange(year=2023, month=3, day=8, hour=14): 0
# PostRange(year=2023, month=3, day=8, hour=17): 3
# PostRange(year=2023, month=3, day=8, hour=18): 2
# PostRange(year=2023, month=3, day=8, hour=19): 0
# PostRange(year=2023, month=3, day=8, hour=20): 0
# PostRange(year=2023, month=3, day=8, hour=21): 0
# PostRange(year=2023, month=3, day=8, hour=23): 0
# PostRange(year=2023, month=3, day=9, hour=0): 0
# PostRange(year=2023, month=3, day=9, hour=2): 0
# PostRange(year=2023, month=3, day=9, hour=4): 0
# PostRange(year=2023, month=3, day=9, hour=6): 0
# PostRange(year=2023, month=3, day=9, hour=9): 3
# PostRange(year=2023, month=3, day=9, hour=10): 0
# PostRange(year=2023, month=3, day=9, hour=12): 2
# PostRange(year=2023, month=3, day=9, hour=13): 2
# PostRange(year=2023, month=3, day=9, hour=14): 0
# PostRange(year=2023, month=3, day=9, hour=15): 3
# PostRange(year=2023, month=3, day=9, hour=16): 2
# PostRange(year=2023, month=3, day=9, hour=17): 2
# PostRange(year=2023, month=3, day=9, hour=18): 2
# PostRange(year=2023, month=3, day=9, hour=19): 0
# PostRange(year=2023, month=3, day=9, hour=20): 0
# PostRange(year=2023, month=3, day=9, hour=21): 0
# PostRange(year=2023, month=3, day=9, hour=22): 2
# PostRange(year=2023, month=3, day=10, hour=0): 3
# PostRange(year=2023, month=3, day=10, hour=1): 0
# PostRange(year=2023, month=3, day=10, hour=2): 0
# PostRange(year=2023, month=3, day=10, hour=4): 2
# PostRange(year=2023, month=3, day=10, hour=5): 0
# PostRange(year=2023, month=3, day=10, hour=12): 3
# PostRange(year=2023, month=3, day=10, hour=13): 3
# PostRange(year=2023, month=3, day=10, hour=15): 2
# PostRange(year=2023, month=3, day=10, hour=16): 0
# PostRange(year=2023, month=3, day=10, hour=19): 0
# PostRange(year=2023, month=3, day=10, hour=20): 2
# PostRange(year=2023, month=3, day=10, hour=23): 2
# PostRange(year=2023, month=3, day=11, hour=1): 2
# PostRange(year=2023, month=3, day=11, hour=2): 3
# PostRange(year=2023, month=3, day=11, hour=3): 0
# PostRange(year=2023, month=3, day=11, hour=4): 2
# PostRange(year=2023, month=3, day=11, hour=5): 3
# PostRange(year=2023, month=3, day=11, hour=6): 2
# PostRange(year=2023, month=3, day=11, hour=7): 2
# PostRange(year=2023, month=3, day=11, hour=8): 0
# PostRange(year=2023, month=3, day=11, hour=9): 0
# PostRange(year=2023, month=3, day=11, hour=10): 0
# PostRange(year=2023, month=3, day=11, hour=12): 0
# PostRange(year=2023, month=3, day=11, hour=13): 0
# PostRange(year=2023, month=3, day=11, hour=17): 0
# PostRange(year=2023, month=3, day=11, hour=18): 2
# PostRange(year=2023, month=3, day=11, hour=19): 0
# PostRange(year=2023, month=3, day=11, hour=20): 4
# PostRange(year=2023, month=3, day=11, hour=21): 2
# PostRange(year=2023, month=3, day=11, hour=22): 0
# PostRange(year=2023, month=3, day=11, hour=23): 0
# PostRange(year=2023, month=3, day=12, hour=1): 0
# PostRange(year=2023, month=3, day=12, hour=2): 2
# PostRange(year=2023, month=3, day=12, hour=4): 0
# ...
# PostRange(year=2023, month=4, day=18, hour=14): 0
# PostRange(year=2023, month=4, day=18, hour=15): 0
# PostRange(year=2023, month=4, day=18, hour=16): 0
# PostRange(year=2023, month=4, day=18, hour=19): 0
# PostRange(year=2023, month=4, day=18, hour=21): 0
# PostRange(year=2023, month=4, day=19, hour=5): 0
# PostRange(year=2023, month=4, day=19, hour=7): 2
# PostRange(year=2023, month=4, day=19, hour=8): 0
# PostRange(year=2023, month=4, day=19, hour=9): 2
# PostRange(year=2023, month=4, day=19, hour=10): 0
# PostRange(year=2023, month=4, day=19, hour=13): 2
# PostRange(year=2023, month=4, day=19, hour=19): 0
# PostRange(year=2023, month=4, day=19, hour=20): 0
# PostRange(year=2023, month=4, day=19, hour=21): 0
# PostRange(year=2023, month=4, day=19, hour=22): 2
# PostRange(year=2023, month=4, day=20, hour=1): 0
# PostRange(year=2023, month=4, day=20, hour=3): 0
# PostRange(year=2023, month=4, day=20, hour=5): 0
# PostRange(year=2023, month=4, day=20, hour=6): 2
# PostRange(year=2023, month=4, day=20, hour=9): 2
# PostRange(year=2023, month=4, day=20, hour=10): 2
# PostRange(year=2023, month=4, day=20, hour=11): 0
# PostRange(year=2023, month=4, day=20, hour=13): 2
# PostRange(year=2023, month=4, day=20, hour=15): 0
# PostRange(year=2023, month=4, day=20, hour=16): 0
# PostRange(year=2023, month=4, day=20, hour=18): 0
# PostRange(year=2023, month=4, day=20, hour=22): 0
# PostRange(year=2023, month=4, day=20, hour=23): 0
# PostRange(year=2023, month=4, day=21, hour=1): 0
# PostRange(year=2023, month=4, day=21, hour=2): 0
# PostRange(year=2023, month=4, day=21, hour=5): 2
# PostRange(year=2023, month=4, day=21, hour=6): 0
# PostRange(year=2023, month=4, day=21, hour=9): 0
# PostRange(year=2023, month=4, day=21, hour=10): 2
# PostRange(year=2023, month=4, day=21, hour=11): 0
# PostRange(year=2023, month=4, day=21, hour=12): 2
# PostRange(year=2023, month=4, day=21, hour=15): 2
# PostRange(year=2023, month=4, day=21, hour=16): 0
# PostRange(year=2023, month=4, day=21, hour=17): 2
# PostRange(year=2023, month=4, day=21, hour=18): 0
# PostRange(year=2023, month=4, day=21, hour=21): 0
# PostRange(year=2023, month=4, day=21, hour=23): 0
# PostRange(year=2023, month=4, day=22, hour=0): 2
# PostRange(year=2023, month=4, day=22, hour=1): 2
# PostRange(year=2023, month=4, day=22, hour=2): 2
# PostRange(year=2023, month=4, day=22, hour=3): 2
# PostRange(year=2023, month=4, day=22, hour=5): 0
# PostRange(year=2023, month=4, day=22, hour=6): 0
# PostRange(year=2023, month=4, day=22, hour=7): 0
# PostRange(year=2023, month=4, day=22, hour=9): 2
# PostRange(year=2023, month=4, day=22, hour=11): 0
# PostRange(year=2023, month=4, day=22, hour=12): 2
# PostRange(year=2023, month=4, day=22, hour=15): 3
# PostRange(year=2023, month=4, day=22, hour=16): 0
# PostRange(year=2023, month=4, day=22, hour=18): 2
# PostRange(year=2023, month=4, day=22, hour=22): 0
# PostRange(year=2023, month=4, day=22, hour=23): 2
# PostRange(year=2023, month=4, day=23, hour=1): 0
# PostRange(year=2023, month=4, day=23, hour=2): 0
# PostRange(year=2023, month=4, day=23, hour=5): 0
# PostRange(year=2023, month=4, day=23, hour=6): 2
# PostRange(year=2023, month=4, day=23, hour=7): 0
# PostRange(year=2023, month=4, day=23, hour=9): 2
# PostRange(year=2023, month=4, day=23, hour=10): 0
# PostRange(year=2023, month=4, day=23, hour=11): 2
# PostRange(year=2023, month=4, day=23, hour=12): 0
# PostRange(year=2023, month=4, day=23, hour=13): 0
# PostRange(year=2023, month=4, day=23, hour=15): 0
# PostRange(year=2023, month=4, day=23, hour=16): 0
# PostRange(year=2023, month=4, day=23, hour=17): 2
# PostRange(year=2023, month=4, day=23, hour=18): 2
# PostRange(year=2023, month=4, day=23, hour=19): 0
# PostRange(year=2023, month=4, day=23, hour=20): 0
# PostRange(year=2023, month=4, day=23, hour=21): 0
# PostRange(year=2023, month=4, day=23, hour=23): 0
# PostRange(year=2023, month=4, day=24, hour=0): 0
# PostRange(year=2023, month=4, day=24, hour=3): 0
# PostRange(year=2023, month=4, day=24, hour=4): 0
# PostRange(year=2023, month=4, day=24, hour=5): 0
# PostRange(year=2023, month=4, day=24, hour=7): 2
# PostRange(year=2023, month=4, day=24, hour=8): 0
# PostRange(year=2023, month=4, day=24, hour=9): 0
# PostRange(year=2023, month=4, day=24, hour=12): 2
# PostRange(year=2023, month=4, day=24, hour=19): 0
# PostRange(year=2023, month=4, day=24, hour=21): 0
# PostRange(year=2023, month=4, day=24, hour=22): 2
# PostRange(year=2023, month=4, day=25, hour=4): 0
# PostRange(year=2023, month=4, day=25, hour=5): 0
# PostRange(year=2023, month=4, day=25, hour=6): 0
# PostRange(year=2023, month=4, day=25, hour=14): 0
# PostRange(year=2023, month=4, day=25, hour=15): 0
# PostRange(year=2023, month=4, day=25, hour=16): 3
# PostRange(year=2023, month=4, day=25, hour=17): 0
# PostRange(year=2023, month=4, day=25, hour=18): 0
# PostRange(year=2023, month=4, day=25, hour=19): 0
# PostRange(year=2023, month=4, day=25, hour=21): 2
# PostRange(year=2023, month=4, day=25, hour=22): 0
# PostRange(year=2023, month=4, day=26, hour=0): 0
# PostRange(year=2023, month=4, day=26, hour=2): 0
# PostRange(year=2023, month=4, day=26, hour=5): 0
# PostRange(year=2023, month=4, day=26, hour=7): 0
# PostRange(year=2023, month=4, day=26, hour=9): 0
# PostRange(year=2023, month=4, day=26, hour=10): 2
# PostRange(year=2023, month=4, day=26, hour=12): 2
# PostRange(year=2023, month=4, day=26, hour=14): 2
# PostRange(year=2023, month=4, day=26, hour=15): 0
# PostRange(year=2023, month=4, day=26, hour=16): 2
# PostRange(year=2023, month=4, day=26, hour=20): 0
# PostRange(year=2023, month=4, day=26, hour=22): 0
# PostRange(year=2023, month=4, day=26, hour=23): 0
# PostRange(year=2023, month=4, day=27, hour=0): 0
# PostRange(year=2023, month=4, day=27, hour=2): 0
# PostRange(year=2023, month=4, day=27, hour=3): 2
# PostRange(year=2023, month=4, day=27, hour=4): 0
# PostRange(year=2023, month=4, day=27, hour=6): 0
# PostRange(year=2023, month=4, day=27, hour=7): 0
# PostRange(year=2023, month=4, day=27, hour=9): 2
# PostRange(year=2023, month=4, day=27, hour=10): 2
# PostRange(year=2023, month=4, day=27, hour=11): 2
# PostRange(year=2023, month=4, day=27, hour=13): 2
# PostRange(year=2023, month=4, day=27, hour=17): 0
# PostRange(year=2023, month=4, day=27, hour=18): 0
# PostRange(year=2023, month=4, day=27, hour=19): 0
# PostRange(year=2023, month=4, day=27, hour=20): 2
# PostRange(year=2023, month=4, day=27, hour=22): 2
# PostRange(year=2023, month=4, day=27, hour=23): 0
# PostRange(year=2023, month=4, day=28, hour=2): 0
# PostRange(year=2023, month=4, day=28, hour=3): 0
# PostRange(year=2023, month=4, day=28, hour=4): 0
# PostRange(year=2023, month=4, day=28, hour=5): 0
# PostRange(year=2023, month=4, day=28, hour=7): 2
# PostRange(year=2023, month=4, day=28, hour=10): 0
# PostRange(year=2023, month=4, day=28, hour=15): 2
# PostRange(year=2023, month=4, day=28, hour=19): 0
# PostRange(year=2023, month=4, day=28, hour=22): 0
# PostRange(year=2023, month=4, day=29, hour=1): 0
# PostRange(year=2023, month=4, day=29, hour=2): 2
# PostRange(year=2023, month=4, day=29, hour=5): 0
# PostRange(year=2023, month=4, day=29, hour=9): 0
# PostRange(year=2023, month=4, day=29, hour=11): 3
# PostRange(year=2023, month=4, day=29, hour=16): 0
# PostRange(year=2023, month=4, day=29, hour=17): 0
# PostRange(year=2023, month=4, day=29, hour=20): 0
# PostRange(year=2023, month=4, day=29, hour=23): 0
# PostRange(year=2023, month=4, day=30, hour=0): 0
# PostRange(year=2023, month=4, day=30, hour=1): 0
# PostRange(year=2023, month=4, day=30, hour=3): 0
# PostRange(year=2023, month=4, day=30, hour=5): 0
# PostRange(year=2023, month=4, day=30, hour=6): 0
# PostRange(year=2023, month=4, day=30, hour=7): 0
# PostRange(year=2023, month=4, day=30, hour=10): 0
# PostRange(year=2023, month=4, day=30, hour=12): 0
# PostRange(year=2023, month=4, day=30, hour=13): 0
# PostRange(year=2023, month=4, day=30, hour=17): 0
# PostRange(year=2023, month=4, day=30, hour=18): 2
# PostRange(year=2023, month=4, day=30, hour=20): 0
# PostRange(year=2023, month=4, day=30, hour=22): 0
# PostRange(year=2023, month=5, day=1, hour=4): 3
# PostRange(year=2023, month=5, day=1, hour=5): 2
# PostRange(year=2023, month=5, day=1, hour=8): 2
# PostRange(year=2023, month=5, day=1, hour=16): 2
# PostRange(year=2023, month=5, day=1, hour=17): 2
# PostRange(year=2023, month=5, day=1, hour=18): 2
# PostRange(year=2023, month=5, day=1, hour=19): 2
# PostRange(year=2023, month=5, day=2, hour=11): 2
# PostRange(year=2023, month=5, day=2, hour=17): 3
# PostRange(year=2023, month=5, day=3, hour=0): 2
# PostRange(year=2023, month=5, day=3, hour=3): 2
# PostRange(year=2023, month=5, day=3, hour=6): 2
# PostRange(year=2023, month=5, day=3, hour=15): 2
# PostRange(year=2023, month=5, day=3, hour=21): 2
# PostRange(year=2023, month=5, day=4, hour=7): 3
# PostRange(year=2023, month=5, day=4, hour=11): 2
# PostRange(year=2023, month=5, day=4, hour=14): 2
# PostRange(year=2023, month=5, day=4, hour=17): 2
# PostRange(year=2023, month=5, day=4, hour=18): 2
# PostRange(year=2023, month=5, day=4, hour=19): 2
# PostRange(year=2023, month=5, day=4, hour=22): 2
# PostRange(year=2023, month=5, day=5, hour=1): 2
# PostRange(year=2023, month=5, day=5, hour=6): 2
# PostRange(year=2023, month=5, day=5, hour=10): 2
# PostRange(year=2023, month=5, day=5, hour=15): 2
# PostRange(year=2023, month=5, day=5, hour=17): 2
# PostRange(year=2023, month=5, day=5, hour=19): 2
# PostRange(year=2023, month=5, day=5, hour=23): 3
# PostRange(year=2023, month=5, day=6, hour=3): 2
# PostRange(year=2023, month=5, day=6, hour=5): 2
# PostRange(year=2023, month=5, day=6, hour=8): 2
# PostRange(year=2023, month=5, day=6, hour=19): 2
# PostRange(year=2023, month=5, day=6, hour=20): 2
# PostRange(year=2023, month=5, day=7, hour=0): 2
# PostRange(year=2023, month=5, day=7, hour=5): 2
# PostRange(year=2023, month=5, day=7, hour=6): 2
# PostRange(year=2023, month=5, day=7, hour=7): 2
# PostRange(year=2023, month=5, day=7, hour=15): 3
# PostRange(year=2023, month=5, day=8, hour=4): 2
# PostRange(year=2023, month=5, day=8, hour=21): 2
# PostRange(year=2023, month=5, day=8, hour=22): 2
# PostRange(year=2023, month=5, day=9, hour=2): 3
# PostRange(year=2023, month=5, day=9, hour=5): 2
# PostRange(year=2023, month=5, day=9, hour=6): 2
# PostRange(year=2023, month=5, day=9, hour=11): 2
# PostRange(year=2023, month=5, day=9, hour=13): 2
# PostRange(year=2023, month=5, day=9, hour=17): 2
# PostRange(year=2023, month=5, day=9, hour=18): 2
# PostRange(year=2023, month=5, day=9, hour=22): 2
# PostRange(year=2023, month=5, day=10, hour=3): 2
# PostRange(year=2023, month=5, day=10, hour=20): 2
# PostRange(year=2023, month=5, day=10, hour=23): 2
# PostRange(year=2023, month=5, day=11, hour=3): 2
# PostRange(year=2023, month=5, day=11, hour=11): 2
# PostRange(year=2023, month=5, day=11, hour=13): 2
# PostRange(year=2023, month=5, day=11, hour=14): 2
# PostRange(year=2023, month=5, day=11, hour=15): 2
# PostRange(year=2023, month=5, day=11, hour=16): 2
# PostRange(year=2023, month=5, day=11, hour=19): 2
# PostRange(year=2023, month=5, day=12, hour=9): 2
# PostRange(year=2023, month=5, day=12, hour=12): 2
# PostRange(year=2023, month=5, day=12, hour=17): 3
# PostRange(year=2023, month=5, day=13, hour=0): 2
# PostRange(year=2023, month=5, day=13, hour=1): 2
# PostRange(year=2023, month=5, day=13, hour=6): 2
# PostRange(year=2023, month=5, day=13, hour=9): 2
# PostRange(year=2023, month=5, day=13, hour=11): 2
# PostRange(year=2023, month=5, day=13, hour=12): 2
# PostRange(year=2023, month=5, day=13, hour=17): 2
# PostRange(year=2023, month=5, day=14, hour=0): 2
# PostRange(year=2023, month=5, day=14, hour=7): 2
# PostRange(year=2023, month=5, day=14, hour=18): 2
# PostRange(year=2023, month=5, day=14, hour=23): 2
# PostRange(year=2023, month=5, day=15, hour=10): 2
# PostRange(year=2023, month=5, day=15, hour=18): 2
# PostRange(year=2023, month=5, day=15, hour=22): 2
# PostRange(year=2023, month=5, day=16, hour=8): 2
# PostRange(year=2023, month=5, day=16, hour=12): 2
# PostRange(year=2023, month=5, day=16, hour=14): 2
# PostRange(year=2023, month=5, day=16, hour=15): 2
# PostRange(year=2023, month=5, day=16, hour=16): 2
# PostRange(year=2023, month=5, day=16, hour=19): 2
# PostRange(year=2023, month=5, day=17, hour=10): 2
# PostRange(year=2023, month=5, day=17, hour=18): 2
# PostRange(year=2023, month=5, day=18, hour=0): 2
# PostRange(year=2023, month=5, day=18, hour=4): 2
# PostRange(year=2023, month=5, day=18, hour=8): 2
# PostRange(year=2023, month=5, day=19, hour=1): 2
# PostRange(year=2023, month=5, day=19, hour=2): 2
# PostRange(year=2023, month=5, day=19, hour=4): 3
# PostRange(year=2023, month=5, day=19, hour=13): 2
# PostRange(year=2023, month=5, day=19, hour=14): 2
# PostRange(year=2023, month=5, day=19, hour=21): 3
# PostRange(year=2023, month=5, day=20, hour=0): 2
# PostRange(year=2023, month=5, day=20, hour=1): 2
# PostRange(year=2023, month=5, day=21, hour=5): 2
# PostRange(year=2023, month=5, day=21, hour=6): 2
# PostRange(year=2023, month=5, day=21, hour=10): 2
# PostRange(year=2023, month=5, day=21, hour=12): 2
# PostRange(year=2023, month=5, day=21, hour=14): 2
# PostRange(year=2023, month=5, day=21, hour=17): 2
# PostRange(year=2023, month=5, day=22, hour=2): 2
# PostRange(year=2023, month=5, day=23, hour=2): 2
# PostRange(year=2023, month=5, day=23, hour=9): 2
# PostRange(year=2023, month=5, day=23, hour=10): 2
# PostRange(year=2023, month=5, day=23, hour=14): 2
# PostRange(year=2023, month=5, day=24, hour=7): 2
# PostRange(year=2023, month=5, day=24, hour=9): 2
# PostRange(year=2023, month=5, day=25, hour=2): 2
# PostRange(year=2023, month=5, day=25, hour=4): 2
# PostRange(year=2023, month=5, day=25, hour=6): 2
# PostRange(year=2023, month=5, day=25, hour=7): 3
# PostRange(year=2023, month=5, day=25, hour=11): 2
# PostRange(year=2023, month=5, day=25, hour=16): 2
# PostRange(year=2023, month=5, day=25, hour=20): 2
# PostRange(year=2023, month=5, day=26, hour=7): 2
# PostRange(year=2023, month=5, day=26, hour=15): 2
# PostRange(year=2023, month=5, day=26, hour=17): 3
# PostRange(year=2023, month=5, day=26, hour=20): 3
# PostRange(year=2023, month=5, day=26, hour=21): 2
# PostRange(year=2023, month=5, day=27, hour=0): 2
# PostRange(year=2023, month=5, day=27, hour=1): 2
# PostRange(year=2023, month=5, day=27, hour=10): 2
# PostRange(year=2023, month=5, day=28, hour=0): 2
# PostRange(year=2023, month=5, day=28, hour=8): 2
# PostRange(year=2023, month=5, day=28, hour=11): 2
# PostRange(year=2023, month=5, day=28, hour=12): 2
# PostRange(year=2023, month=5, day=28, hour=19): 2
# PostRange(year=2023, month=5, day=28, hour=20): 2
# PostRange(year=2023, month=5, day=28, hour=22): 2
# PostRange(year=2023, month=5, day=28, hour=23): 2
# PostRange(year=2023, month=5, day=29, hour=2): 2
# PostRange(year=2023, month=5, day=29, hour=6): 2
# PostRange(year=2023, month=5, day=29, hour=12): 2
# PostRange(year=2023, month=5, day=29, hour=13): 2
# PostRange(year=2023, month=5, day=29, hour=14): 2
# PostRange(year=2023, month=5, day=29, hour=15): 2
# PostRange(year=2023, month=5, day=29, hour=17): 2
# PostRange(year=2023, month=5, day=30, hour=9): 3
# PostRange(year=2023, month=5, day=30, hour=10): 2
# PostRange(year=2023, month=5, day=30, hour=11): 2
# PostRange(year=2023, month=5, day=30, hour=14): 2
# PostRange(year=2023, month=5, day=30, hour=19): 2
# PostRange(year=2023, month=5, day=30, hour=21): 2
# PostRange(year=2023, month=5, day=30, hour=23): 2
# PostRange(year=2023, month=5, day=31, hour=4): 2
# PostRange(year=2023, month=5, day=31, hour=6): 3
# PostRange(year=2023, month=5, day=31, hour=8): 3
# PostRange(year=2023, month=5, day=31, hour=12): 2
# PostRange(year=2023, month=5, day=31, hour=13): 3
# PostRange(year=2023, month=5, day=31, hour=19): 2
# PostRange(year=2023, month=6, day=1, hour=3): 2
# PostRange(year=2023, month=6, day=1, hour=5): 2
# PostRange(year=2023, month=6, day=1, hour=7): 2
# PostRange(year=2023, month=6, day=1, hour=8): 2
# PostRange(year=2023, month=6, day=1, hour=10): 2
# PostRange(year=2023, month=6, day=1, hour=13): 2
# PostRange(year=2023, month=6, day=1, hour=17): 2
# PostRange(year=2023, month=6, day=2, hour=1): 2
# PostRange(year=2023, month=6, day=2, hour=11): 2
# PostRange(year=2023, month=6, day=2, hour=13): 2
# PostRange(year=2023, month=6, day=2, hour=16): 2
# PostRange(year=2023, month=6, day=3, hour=7): 2
# PostRange(year=2023, month=6, day=3, hour=8): 2
# PostRange(year=2023, month=6, day=3, hour=9): 4
# PostRange(year=2023, month=6, day=3, hour=11): 2

# %%
def search_md_c():
    with db.get_session() as session:
            query = select(DBPost)
            # Platform is required
            query = query.where(DBPost.platform == "twitter")
            query = query.where(DBPost.metadata_content["labels"].contains("test_selection"))
            result = session.execute(query)
            for post in result.scalars():
                yield post.model()

for a in search_md_c():
    print(a.metadata_content.labels)
    break
# Out:
# ['test_selection']
